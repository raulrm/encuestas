# %%
import numpy as np
import pandas as pd
import pyreadstat
import os

# %%
# mostrar todas las columnas del pandas
pd.options.display.max_columns = None

# %%
# Con esto obtenemos la lista de archivos spss del directorio /archivos

ruta_directorio = './archivos/'  # ruta del directorio que contiene los archivos .sav
lista_archivos = []

for archivo in os.listdir(ruta_directorio):
    if archivo.endswith('.sav'):
        lista_archivos.append(archivo)

print(lista_archivos)
# Out:
# ['Base Nacional Abril.n3.sav', 'Copia de Base CABA Julio- Agosto.c1.sav', 'Base Uspallata Julio.n2.sav', 'Nacional.n7.sav', 'Base Nacional Final.n1.sav', 'Base CABA Julio- Agosto.c1.sav', 'Nacional.n6.sav', 'Nacional Noviembre pond 06-11-23 CON voto anterior.n5.sav', 'Base PBA Julio Uspallata con agregados de casos CATI.p1.sav', 'PBA ponderada 10-10-23.p2.sav', 'Base Nacional VF.n4.sav']

# %%
archivo = './archivos/'+'Base Nacional Abril.n3.sav'

# %%
df, meta = pyreadstat.read_sav(archivo)
df.sample(3)
# Out:
#      plaza  estrato  Sexo  Edad  estudios   p4   p5   p6   p7   p8   p9  p10  \
# 199    2.0      2.0   1.0   2.0       2.0  3.0  2.0  1.0  2.0  3.0  3.0  1.0
# 991    2.0      2.0   1.0   4.0       1.0  1.0  1.0  2.0  3.0  3.0  2.0  3.0
# 494    2.0      2.0   1.0   2.0       2.0  3.0  2.0  2.0  2.0  3.0  3.0  1.0
#
#      p11  p12  p13  p14  p15  p16  p17  p18  p19  p20  p21  p22  p23  p24  \
# 199  3.0  2.0  3.0  3.0  8.0  8.0  8.0  8.0  8.0  5.0  2.0  3.0  4.0  2.0
# 991  1.0  2.0  2.0  2.0  4.0  4.0  6.0  7.0  5.0  1.0  6.0  3.0  3.0  3.0
# 494  3.0  3.0  3.0  3.0  8.0  8.0  8.0  8.0  8.0  5.0  2.0  5.0  4.0  2.0
#
#      p25  p26  p27  p28  p29  p30  p31  p32  p33  p34  p35   p36  p37  p38  \
# 199  5.0  5.0  4.0  3.0  4.0  2.0  2.0  2.0  5.0  2.0  5.0  10.0  7.0  1.0
# 991  3.0  4.0  2.0  1.0  3.0  2.0  3.0  5.0  5.0  2.0  2.0   1.0  1.0  1.0
# 494  2.0  2.0  3.0  3.0  3.0  3.0  2.0  1.0  2.0  3.0  2.0   9.0  7.0  1.0
#
#      LARRETA  MANES  VIDAL  CFK  SCIOLI  MACRI  MASSA  BULLRICH  MILEI  \
# 199      1.0    3.0    3.0  2.0     2.0    2.0    1.0       1.0    1.0
# 991      2.0    2.0    2.0  1.0     1.0    2.0    1.0       2.0    3.0
# 494      1.0    1.0    1.0  2.0     2.0    2.0    2.0       1.0    1.0
#
#      LOUSTEAU  KICILLOF  SANTILLI  zona  weight
# 199       3.0       1.0       3.0   1.0   0.711
# 991       3.0       1.0       1.0   1.0   0.711
# 494       1.0       2.0       1.0   1.0   0.711

# %%
df = pd.read_spss(archivo)
df.sample(3)
# Out:
#              plaza estrato    Sexo                Edad  \
# 167    Resistencia       5  Hombre    Mayor de 50 años
# 394  Mar del Plata       4   Mujer  Entre 18 y 29 años
# 608       La Plata       4  Hombre  Entre 30 y 49 años
#
#                                               estudios  \
# 167  Nivel Universitario o Terciario, ya sea comple...
# 394     Nivel Secundario, ya sea completo o incompleto
# 608     Nivel Secundario, ya sea completo o incompleto
#
#                                          p4  \
# 167  Vuelva a gobernar Juntos por el Cambio
# 394  Vuelva a gobernar Juntos por el Cambio
# 608      Gobierne un partido político nuevo
#
#                                                   p5  \
# 167    Un liderazgo que genere diálogo y  consensos
# 394  Un liderazgo firme y capaz de imponer sus ideas
# 608              No sabe // no tiene opinión formada
#
#                                     p6                       p7  \
# 167              Si, es un impedimento  Podría llegar a votarlo
# 394              Si, es un impedimento  Podría llegar a votarlo
# 608  No sabe/ no tiene opinión formada  Podría llegar a votarlo
#
#                           p8                p9                      p10  \
# 167  Podría llegar a votarlo  Nunca lo votaría         Nunca lo votaría
# 394        Seguro lo votaría  Nunca lo votaría  Podría llegar a votarlo
# 608         Nunca lo votaría  Nunca lo votaría        Seguro lo votaría
#
#                   p11                      p12                p13  \
# 167  Nunca lo votaría         Nunca lo votaría   Nunca lo votaría
# 394  Nunca lo votaría         Nunca lo votaría   Nunca lo votaría
# 608  Nunca lo votaría  Podría llegar a votarlo  Seguro lo votaría
#
#                                                    p14  \
# 167  Juntos por el Cambio de Bullrich, Macri y Larreta
# 394  Juntos por el Cambio de Bullrich, Macri y Larreta
# 608                                     Otro candidato
#
#                                             p15  \
# 167                                    Indeciso
# 394  Patricia Bullrich por Juntos por el Cambio
# 608            Javier Milei por Avanza Libertad
#
#                                             p16  \
# 167                                    Indeciso
# 394  Patricia Bullrich por Juntos por el Cambio
# 608            Javier Milei por Avanza Libertad
#
#                                             p17  \
# 167                                    Indeciso
# 394  Patricia Bullrich por Juntos por el Cambio
# 608       Axel Kicillof  por el Frente de Todos
#
#                                             p18  \
# 167                                    Indeciso
# 394  Patricia Bullrich por Juntos por el Cambio
# 608            Javier Milei por Avanza Libertad
#
#                                                    p19  \
# 167                                           Indeciso
# 394  Horacio Rodríguez Larreta por Juntos por el Ca...
# 608           Juan Schiaretti por el peronismo federal
#
#                                                    p20  \
# 167  Horacio Rodríguez Larreta por Juntos por el Ca...
# 394  Horacio Rodríguez Larreta por Juntos por el Ca...
# 608  Horacio Rodríguez Larreta por Juntos por el Ca...
#
#                                                    p21  \
# 167  Horacio Rodríguez Larreta por Juntos por el Ca...
# 394  Horacio Rodríguez Larreta por Juntos por el Ca...
# 608                    Javier Milei de Avanza Libertad
#
#                                                    p22  \
# 167  Horacio Rodríguez Larreta por Juntos por el Ca...
# 394  Horacio Rodríguez Larreta por Juntos por el Ca...
# 608                                           Indeciso
#
#                                  p23    p24        p25        p26       p27  \
# 167               Ninguno de los dos  Buena      Buena      Buena  Muy mala
# 394  Javier Milei de Avanza Libertad  Buena      Buena      Buena  Muy mala
# 608  Javier Milei de Avanza Libertad   Mala  Muy buena  Muy buena  Muy mala
#
#           p28        p29        p30        p31        p32        p33  \
# 167  Muy mala   Muy mala   Muy mala       Mala   Muy mala  Muy buena
# 394  Muy mala      Buena   Muy mala  Muy buena      Buena      Buena
# 608  Muy mala  Muy buena  Muy buena       Mala  Muy buena      Ns/Nc
#
#            p34        p35                                   p36  \
# 167   Muy mala        NaN                                   NaN
# 394   Muy mala      Buena           Cristian Ritondo por Juntos
# 608  Muy buena  Muy buena  Axel Kicillof por el Frente de Todos
#
#                                   p37      p38   LARRETA     MANES     VIDAL  \
# 167                   Roberto Lavagna   Muchas  Positiva  Positiva  Positiva
# 394  Mauricio Macri y Miguel Pichetto   Muchas  Positiva  Positiva  Positiva
# 608  Mauricio Macri y Miguel Pichetto  Algunas  Negativa  Positiva  Positiva
#
#           CFK    SCIOLI     MACRI     MASSA  BULLRICH     MILEI  LOUSTEAU  \
# 167  Negativa  Negativa  Negativa  Negativa  Negativa  Negativa  Positiva
# 394  Negativa  Negativa  Positiva  Negativa  Positiva  Positiva  Positiva
# 608  Negativa  Negativa  Positiva  Positiva  Negativa  Positiva     Ns Nr
#
#      KICILLOF  SANTILLI     zona    weight
# 167  Negativa       NaN  Grandes  1.197000
# 394  Negativa  Positiva  Grandes  0.876652
# 608  Positiva  Positiva  Grandes  0.917000

# %%
dict_labels = meta.column_names_to_labels
dict_labels
# Out:
# {'plaza': 'Ciudad',
#  'estrato': 'Estrato Nacional',
#  'Sexo': None,
#  'Edad': None,
#  'estudios': None,
#  'p4': 'P4. Pensando en las elecciones a Presidente del 2023 ¿usted prefiere que…?',
#  'p5': 'P5. ¿Qué tipo de liderazgo presidencial necesita el país para mejorar?',
#  'p6': 'P6. La grieta política entre kirchneristas y antikirichneristas, ¿es un impedimento para que el país mejore?',
#  'p7': 'Horacio Rodriguez Larreta',
#  'p8': 'Patricia Bullrich',
#  'p9': 'Daniel Scioli',
#  'p10': 'Javier Milei',
#  'p11': 'Cristina Kirchner',
#  'p12': 'Sergio Massa',
#  'p13': 'Axel Kicillof',
#  'p14': 'P14. Si mañana fuesen las elecciones presidenciales, ¿a qué espacio político votaría?',
#  'p15': 'P15. Y si mañana fueran las elecciones PASO, usted ¿a quién votaría?',
#  'p16': 'P16. Y si mañana fueran las elecciones PASO, usted ¿a quién votaría?',
#  'p17': 'P17. Y si mañana fueran las elecciones PASO, usted ¿a quién votaría?',
#  'p18': 'P18. Y si mañana fueran las elecciones PASO, usted ¿a quién votaría?',
#  'p19': 'P19. Y si mañana fueran las elecciones PASO, usted ¿a quién votaría?',
#  'p20': 'P20. Si mañana hubiera BALLOTAGE para elegir el próximo presidente de la Nación ¿A quién votaría?',
#  'p21': 'P21. Si mañana hubiera BALLOTAGE para elegir el próximo presidente de la Nación ¿A quién votaría?',
#  'p22': 'P22. Si mañana hubiera BALLOTAGE para elegir el próximo presidente de la Nación ¿A quién votaría?',
#  'p23': 'P23. Si mañana hubiera BALLOTAGE para elegir el próximo presidente de la Nación ¿A quién votaría?',
#  'p24': 'Horacio Rodriguez Larreta',
#  'p25': 'Facundo Manes',
#  'p26': 'María Eugenia Vidal',
#  'p27': 'Cristina Kirchner',
#  'p28': 'Daniel Scioli',
#  'p29': 'Mauricio Macri',
#  'p30': 'Sergio Massa',
#  'p31': 'Patricia Bullrich',
#  'p32': 'Javier Milei',
#  'p33': 'Martín Lousteau',
#  'p34': 'Axel Kicillof',
#  'p35': 'Diego Santilli',
#  'p36': 'P36. Si las elecciones a Gobernador de Buenos Aires fueran mañana, ¿a quien votaría?\xa0',
#  'p37': 'P37. Para terminar, ¿a quién votó en las elecciones 2019?',
#  'p38': 'P38. ¿Qué probabilidades hay que vaya a votar el día de las elecciones?',
#  'LARRETA': None,
#  'MANES': None,
#  'VIDAL': None,
#  'CFK': None,
#  'SCIOLI': None,
#  'MACRI': None,
#  'MASSA': None,
#  'BULLRICH': None,
#  'MILEI': None,
#  'LOUSTEAU': None,
#  'KICILLOF': None,
#  'SANTILLI': None,
#  'zona': None,
#  'weight': None}

# %%
dict_labels = meta.column_names_to_labels
type(dict_labels)
# Out:
# dict

# %%
    meta.value_labels
# Out:
# {'labels0': {1.0: 'IVR', 2.0: 'Presencial'},
#  'labels1': {1.0: 'Quilmes',
#   2.0: 'Lomas de Zamora',
#   3.0: 'Lanús',
#   4.0: 'La Matanza',
#   5.0: 'F Varela',
#   6.0: 'P Indio',
#   7.0: 'P Perón',
#   8.0: 'Ezeiza',
#   9.0: 'E Echeverría',
#   10.0: 'Ensenada',
#   11.0: 'Cañuelas',
#   12.0: 'Berisso',
#   13.0: 'Berazategui',
#   14.0: 'Avellaneda',
#   15.0: 'A Brown',
#   16.0: 'V Lopez',
#   17.0: 'Tres de Febrero',
#   18.0: 'Tigre',
#   19.0: 'Suipacha',
#   20.0: 'San MIguel',
#   21.0: 'S Isidro',
#   22.0: 'San Fernando',
#   23.0: 'Pilar',
#   24.0: 'Malvinas Arg',
#   25.0: 'Morón',
#   26.0: 'Navarro',
#   27.0: 'Moreno',
#   28.0: 'Merlo',
#   29.0: 'José C Paz',
#   30.0: 'Merlo',
#   31.0: 'Hurlingham',
#   32.0: 'San Martín',
#   33.0: 'Escobar',
#   34.0: 'Lujan',
#   35.0: 'Ituzaingo',
#   36.0: 'Beriso',
#   37.0: 'Cañuelas',
#   38.0: 'Lujan',
#   39.0: 'Ituzaingó',
#   40.0: 'San Vicente',
#   41.0: 'M Paz',
#   42.0: 'Mercedes',
#   43.0: 'PIlar',
#   44.0: 'G Rodriguez',
#   45.0: 'Estrato3',
#   46.0: 'Estrato4',
#   47.0: 'Estrato5',
#   48.0: 'Estrato6',
#   49.0: 'Estrato7',
#   50.0: 'San Vicente'},
#  'labels2': {1.0: 'Primera',
#   2.0: 'Tercera',
#   3.0: '3',
#   4.0: '4',
#   5.0: '5',
#   6.0: '6',
#   7.0: '7'},
#  'labels3': {1.0: 'Masculino', 2.0: 'Femenino'},
#  'labels4': {1.0: 'Menor de 18 años',
#   2.0: 'Entre 18 y 29 años',
#   3.0: 'Entre 30 y 49 años',
#   4.0: 'Mayor de 50 años'},
#  'labels5': {1.0: 'Nivel Primario, ya sea completo o incompleto',
#   2.0: 'Nivel Secundario, ya sea completo o incompleto',
#   3.0: 'Nivel Universitario o Terciario, ya sea completo o incompleto'},
#  'labels6': {1.0: 'La Desocupación',
#   2.0: 'La Inflación',
#   3.0: 'La salud pública y el estado de los hospitales',
#   4.0: 'La Educación y el estado de las escuelas',
#   5.0: 'La Inseguridad',
#   6.0: 'La Corrupción',
#   7.0: 'Otro',
#   8.0: 'No sabe / no tiene opinión formada'},
#  'labels7': {1.0: 'El gobierno anterior de Mauricio Macri',
#   2.0: 'El gobierno actual de Alberto Fernández',
#   3.0: 'No sabe / no tiene opinión formada'},
#  'labels8': {1.0: 'El actual gobierno de Axel Kicillof',
#   2.0: 'El anterior gobierno de María Eugenia Vidal',
#   3.0: 'Todos los políticos y gobiernos por igual'},
#  'labels9': {1.0: 'Muy Positiva',
#   2.0: 'Algo Positiva',
#   3.0: 'Algo Negativa',
#   4.0: 'Muy Negativa',
#   5.0: 'No sabe no tiene opinión formada'},
#  'labels10': {1.0: 'Muy Positiva',
#   2.0: 'Algo Positiva',
#   3.0: 'Algo Negativa',
#   4.0: 'Muy Negativa',
#   5.0: 'No sabe no tiene opinión formada'},
#  'labels11': {1.0: 'Muy Positiva',
#   2.0: 'Algo Positiva',
#   3.0: 'Algo Negativa',
#   4.0: 'Muy Negativa',
#   5.0: 'No sabe no tiene opinión formada'},
#  'labels12': {1.0: 'Muy Positiva',
#   2.0: 'Algo Positiva',
#   3.0: 'Algo Negativa',
#   4.0: 'Muy Negativa',
#   5.0: 'No sabe no tiene opinión formada'},
#  'labels13': {1.0: 'Muy Positiva',
#   2.0: 'Algo Positiva',
#   3.0: 'Algo Negativa',
#   4.0: 'Muy Negativa',
#   5.0: 'No sabe no tiene opinión formada'},
#  'labels14': {1.0: 'Muy Positiva',
#   2.0: 'Algo Positiva',
#   3.0: 'Algo Negativa',
#   4.0: 'Muy Negativa',
#   5.0: 'No sabe no tiene opinión formada'},
#  'labels15': {1.0: 'Muy Positiva',
#   2.0: 'Algo Positiva',
#   3.0: 'Algo Negativa',
#   4.0: 'Muy Negativa',
#   5.0: 'No sabe no tiene opinión formada'},
#  'labels16': {1.0: 'Juntos por el Cambio de Larreta y Macri',
#   2.0: 'Frente de Todos de Alberto Fernández y Cristina Kirchner',
#   3.0: 'Los libertarios de JavierMilei',
#   4.0: 'Frente de Izquierda',
#   5.0: 'Peronismo federal de Juan Schiaretti y Juan Manuel Urtubey',
#   6.0: 'Otro',
#   7.0: 'No sabe está indeciso',
#   8.0: 'Blanco'},
#  'labels17': {1.0: 'Daniel Scioli',
#   2.0: 'Sergio Massa',
#   3.0: 'Horacio Rodríguez Larreta',
#   4.0: 'Patricia Bullrich',
#   5.0: 'Javier Milei',
#   6.0: 'Juan Schiaretti',
#   7.0: 'Nicolás del Caño',
#   8.0: 'No sabe / está indeciso',
#   9.0: 'En blanco'},
#  'labels18': {1.0: 'Axel Kicillof del Frente de Todos',
#   2.0: 'Diego Santilli de Juntos',
#   3.0: 'Martín Tetaz de Juntos',
#   4.0: 'Cristian Ritondo de Juntos',
#   5.0: 'Carolina Píparo de los libertarios de Javier Milei',
#   6.0: 'Fernando Burlando por el Movimiento de Integración Federal',
#   7.0: 'Néstor Pitrola por el Frente de Izquierda',
#   8.0: 'No sabe / está indeciso',
#   9.0: 'En blanco'},
#  'labels19': {1.0: 'Axel Kicillof',
#   2.0: 'Diego Santilli',
#   3.0: 'Carolina Píparo',
#   4.0: 'Fernando Burlando',
#   5.0: 'Florencio Randazzo',
#   6.0: 'Romina del Plá',
#   7.0: 'Otro',
#   8.0: 'No sabe / está indeciso',
#   9.0: 'En blanco'},
#  'labels20': {1.0: 'Sergio Massa y Axel Kicillof por el Frente de Todos',
#   2.0: 'Horacio Rodríguez Larreta y Diego Santilli por Juntos',
#   3.0: 'Javier Milei y Carolina Píparo por La Libertad Avanza',
#   4.0: 'Juan Schiaretti y Florencio Randazzo por el peronismo federal',
#   5.0: 'Nicolás del Caño y Romina Del Plá por el Frente de Izqueirda',
#   6.0: 'Otro',
#   7.0: 'No sabe / está indeciso',
#   8.0: 'En blanco'},
#  'labels21': {1.0: 'Daniel Scioli y Axel Kicillof por el Frente de Todos',
#   2.0: 'Patricia Bullrich y Cristian Ritondo ypor Juntos',
#   3.0: 'Javier Milei y Carolina Píparo por La Libertad Avanza',
#   4.0: 'Juan Schiaretti y Florencio Randazzo por el peronismo federal',
#   5.0: 'Nicolás del Caño y Romina del Plá por el Frente de Izqueirda',
#   6.0: 'Otro',
#   7.0: 'No sabe / está indeciso',
#   8.0: 'En blanco'},
#  'labels22': {1.0: 'Primera', 2.0: 'Tercera', 3.0: 'Interior'},
#  'labels23': {1.0: 'Positivo', 2.0: 'Negativo', 5.0: 'Ns Nr'}}
