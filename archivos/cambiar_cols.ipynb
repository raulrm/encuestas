# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import glob, os
from pathlib import Path
import pyreadstat

# print(pd.__version__)
# Configuro estilo seaborn
sns.set_theme(style='ticks', context='talk', palette='tab10')

# Suprimo los warnings
import warnings
warnings.simplefilter(action='ignore', category=(FutureWarning, UserWarning))

from ydata_profiling import ProfileReport
import dtale

# %%
# mostrar todas las columnas del pandas
pd.options.display.max_columns = None

# %%
# encuesta = "Base Nacional Final.n1.sav"
encuesta = "PBA ponderada 10-10-23.p2.sav"

# %%
df, meta = pyreadstat.read_sav(encuesta)

# %%
df = pd.read_spss(encuesta)
df.sample(3)
# Out:
#     Metodo        plaza  Estrato        Sexo       Edad  \
# 493    IVR  San Vicente  Tercera   2 - Mujer    18 a 29
# 707    IVR          NaN        5   2 - Mujer  Más de 50
# 429    IVR   La Matanza  Tercera  1 - Hombre  Más de 50
#
#                                               estudios                P4  \
# 493  3 - Nivel Universitario o Terciario, ya sea co...  4 - Muy negativa
# 707   1 - Nivel Primario, ya sea completo o incompleto  4 - Muy negativa
# 429  3 - Nivel Universitario o Terciario, ya sea co...  1 - Muy positiva
#
#                     P5                 P6                P7  \
# 493   4 - Muy negativa          5 - Ns/Nc  1 - Muy positiva
# 707  2 - Algo positiva  2 - Algo positiva  4 - Muy negativa
# 429   4 - Muy negativa  3 - Algo negativa  1 - Muy positiva
#
#                                             P8  \
# 493                   No sabe // Está indeciso
# 707  Patricia Bullrich de Juntos por el cambio
# 429       Sergio Massa de Unidos por la patria
#
# ...

# %%
# listar columnas
listado = df.columns
print(listado)
# Out:
# Index(['Metodo', 'plaza', 'Estrato', 'Sexo', 'Edad', 'estudios', 'P4', 'P5',
#        'P6', 'P7', 'P8', 'P9', 'P10', 'P11', 'P12', 'P13', 'P14', 'P15', 'P16',
#        'P17', 'P18', 'pondedad', 'pondestudios', 'pondedadestudios',
#        'pondestrato', 'pondedadestudiosestrato', 'pondestudios2',
#        'pondedadestudiosestratoestudios2', 'pondedad2',
#        'pondedadestudiosestratoestudios2edad2', 'pondsexo',
#        'pondedadestudiosestratoestudios2edad2sexo', 'pondvotant',
#        'pondedadestudiosestratoestudios2edad2sexovotant', 'pondestrato2',
#        'pondedadestudiosestratoestudios2edad2sexovotantestrato2', 'pondedad3',
#        'pondedadestudiosestratoestudios2edad2sexovotantestrato2edad3',
#        'IMAGEN_MASSA', 'IMAGEN_MILEI', 'IMAGEN_BULLRICH', 'IMAGEN_KICILLOF',
#        'IMAGEN_PÍPARO', 'IMAGEN_GRINDETTI'],
#       dtype='object')

# %%
dict_labels = meta.column_names_to_labels
dict_labels
# Out:
# {'Metodo': None,
#  'plaza': 'Ciudad',
#  'Estrato': 'Estrato Provincial',
#  'Sexo': 'Sexo',
#  'Edad': 'Edad',
#  'estudios': 'Educación',
#  'P4': '¿ Qué imagen tiene de Sergio Massa?',
#  'P5': '¿ Qué imagen tiene de Javier Milei?',
#  'P6': '¿ Qué imagen tiene de Patricia Bullrich?',
#  'P7': '¿ Qué imagen tiene de Axel Kiciloff?',
#  'P8': 'Si las elecciones presidenciales fueran mañana, ¿a qué formula votaría?',
#  'P9': 'Si Sergio Massa y Javier Milei ingresaran al ballotage en noviembre, a qué político votaría?',
#  'P10': 'Si Patricia Bullrichy Javier Milei ingresaran al ballotage en noviembre, a qué político votaría?',
#  'P11': 'Si Patricia Bullrichy Sergio Massa ingresaran al ballotage en noviembre, a qué político votaría?',
#  'P12': 'Para Ud, ¿quién ganó el debate presidencial del domingo 1ro de octubre?',
#  'P13': 'Si las elecciones a gobernador fueran mañana, ¿a qué candidato votaría?',
#  'P14': '¿ Qué imagen tiene de Carolina Piparo?',
# ...

# %%
listado_nuevo = [dict_labels[item] for item in listado]
listado_nuevo
# Out:
# ['Metodo',
#  'comuna',
#  'Sexo',
#  'Rango de edad',
#  'Estudios',
#  'Patricia Bullrich',
#  'Horacio Rodríguez Larreta',
#  'Martín Lousteau',
#  'Jorge Macri',
#  'Sergio Massa',
#  'Posibilidad de voto Martín Lousteau',
#  'Posibilidad de voto Jorge Macri',
#  'PASO Jefe de gobierno',
#  'Usted votaría a Martin Lousteau  en la interna de Juntos para evitar que gane Jorge Macri',
#  'PASO Presidente',
#  'Posibilidad existe que vaya a votar en las paso del 13 de agosto',
#  'Voto legislativas 2021',
#  '(no var label)']

# %% [markdown]
# listado_nuevo = ['metodo', 'plaza', 'region', 'sexo', 'edad', 'educacion', 'imagen_massa', 'imagen_milei', 'teme', 'votara_milei',
#        'votara_massa', 'ballotage_votara', 'votara_hoy', 'p9_p10', 'combinada', 'general_voto', 'weight1', 'weight2',
#        'cr1', 'cr2', 'cr3', 'cr4', 'cr5', 'cr6', 'cr7', 'cr8', 'cr9', 'cr10',
#        'cr11']

# %% [markdown]
# listado_nuevo = ['plaza', 'estrato', 'metodo', 'sexo', 'edad', 'estudios', 'paso_sufragara', 'paso_votaria',
#        'p5o', 'p6', 'paso_importa', 'pondedad', 'pondestudios', 'pondedadestudios',
#        'pondestrato', 'pondedadestudiosestrato', 'pondestudios2',
#        'pondedadestudiosestratoestudios2', 'pondedad2',
#        'pondedadestudiosestratoestudios2edad2', 'pondsexo',
#        'pondedadestudiosestratoestudios2edad2sexo', 'PROBABILIDAD_VOTO_PASO',
#        'IMPORTANCIA_PASO']

# %% [markdown]
# listado_nuevo = ['caso', 'plaza', 'geografía', 'estrato1', 'estrato1agrup', 'estrato2',
#        'partidogba', 'sexo', 'edad', 'estudios', 'p4', 'p5', 'p6', 'p7', 'p8',
#        'p9', 'p10', 'p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17', 'p18',
#        'p19', 'p20', 'p21', 'p22', 'p23', 'p24', 'p25', 'p25o', 'p26', 'p27',
#        'p28', 'p29', 'p30', 'p31', 'p32', 'p33', 'p34', 'p35', 'p36', 'p37',
#        'pondedad', 'pondestudios', 'pondedadestudios', 'pondestrato1',
#        'pondedadestudiosestrato1', 'pondestudios2',
#        'pondedadestudiosestrato1estudios2', 'pondedad2',
#        'pondedadestudiosestrato1estudios2edad2', 'pondsexo',
#        'pondedadestudiosestrato1estudios2edad2sexo', 'pondestrato12',
#        'pondedadestudiosestrato1estudios2edad2sexoestrato12', 'imagen_larreta',
#        'imagen_macri', 'imagen_milei', 'imagen_cfk', 'imagen_massa',
#        'imagen_morales', 'imagen_bullrich', 'imagen_kicillof',
#        'imagen_santilli', 'imagen_grindetti', 'imagen_piparo', 'INTERÉS',
#        'PROBABILIDAD_DE_IR_A_VOTAR', 'VOTO_PARTIDO']

# %% [markdown]
# listado_nuevo = ['metodo', 'plaza', 'geografía', 'sexo', 'años', 'edad', 'estudios', 'general_votaria',
# 'ballotage_votaria', 'p6', 'p7', 'paso_voto', 'pondedad', 'pondestudios', 'pondedadestudios',
# 'pondZonapais', 'pondedadestudiosZonapais', 'pondestudios2',
# 'pondedadestudiosZonapaisestudios2', 'pondedad2',
# 'pondedadestudiosZonapaisestudios2edad2', 'pondsexo',
# 'pondedadestudiosZonapaisestudios2edad2sexo', 'pondZonapais2',
# 'pondedadestudiosZonapaisestudios2edad2sexoZonapais2', 'pondvotant',
# 'pondedadestudiosZonapaisestudios2edad2sexoZonapais2votant', 'ponde3',
# 'pondedadestudiosZonapaisestudios2edad2sexoZonapais2votante3']

# %% [markdown]
# listado_nuevo = ['metodo', 'geografía', 'sexo', 'edad', 'estudios', 'P4', 'P5', 'P6',
#        'P7', 'P8', 'P9', 'P10', 'P11', 'P12', 'P13', 'P14', 'P15', 'P24',
#        'pondedad', 'pondestudios', 'pondedadestudios', 'pondZonapais',
#        'pondedadestudiosZonapais', 'pondestudios2',
#        'pondedadestudiosZonapaisestudios2', 'pondedad2',
#        'pondedadestudiosZonapaisestudios2edad2', 'pondsexo',
#        'pondedadestudiosZonapaisestudios2edad2sexo', 'pondZonapais2',
#        'pondedadestudiosZonapaisestudios2edad2sexoZonapais2', 'pondvotant',
#        'pondedadestudiosZonapaisestudios2edad2sexoZonapais2votant', 'pondest3',
#        'pondedadestudiosZonapaisestudios2edad2sexoZonapais2votantest3',
#        'imagen_massa', 'imagen_villaruel', 'imagen_macri', 'imagen_milei',
#        'imagen_bullrich', 'imagen_cfk']

# %% [markdown]
# listado_nuevo = ['plaza', 'estrato1', 'estrato', 'partidogba', 'sexo', 'edad',
#        'estudios', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9', 'p10', 'p11', 'p12',
#        'p13', 'p14', 'p15', 'p16', 'p17', 'ESPACIO', 'p18', 'p19', 'p20',
#        'p21', 'p22', 'p23', 'p24', 'p25', 'p25o', 'p26', 'p27', 'p28', 'p29',
#        'p30', 'p31', 'p32', 'p33', 'p34', 'p35', 'p36', 'PROBAB', 'p37',
#        'INTERES', 'cordon', 'imagen_larreta', 'imagen_macri', 'imagen_milei', 'imagen_cfk', 'imagen_massa',
#        'imagen_morales', 'imagen_bullrich', 'imagen_kicillof', 'imagen_santilli', 'imagen_grindetti', 'imagen_piparo',
#        'weight']

# %% [markdown]
# listado_nuevo = ['metodo', 'plaza', 'estrato', 'sexo', 'edad', 'estudios', 'P4', 'P5',
#        'P6', 'P7', 'P8', 'P9', 'P10', 'P11', 'P12', 'P13', 'P14', 'P15', 'P16',
#        'P17', 'P18', 'pondedad', 'pondestudios', 'pondedadestudios',
#        'pondestrato', 'pondedadestudiosestrato', 'pondestudios2',
#        'pondedadestudiosestratoestudios2', 'pondedad2',
#        'pondedadestudiosestratoestudios2edad2', 'pondsexo',
#        'pondedadestudiosestratoestudios2edad2sexo', 'pondvotant',
#        'pondedadestudiosestratoestudios2edad2sexovotant', 'pondestrato2',
#        'pondedadestudiosestratoestudios2edad2sexovotantestrato2', 'pondedad3',
#        'pondedadestudiosestratoestudios2edad2sexovotantestrato2edad3',
#        'imagen_massa', 'imagen_milei', 'imagen_bulrich', 'imagen_kicillof',
#        'imagen_piparo', 'imagen_grindetti']

# %%
listado_nuevo = ['metodo',
 'comuna',
 'sexo',
 'edad',
 'estudios',
 'imagen_bullrich',
 'imagen_larreta',
 'imagen_lousteau',
 'imagen_jorge_macri',
 'imagen_massa',
 'votaria_lousteau',
 'votaria_jorge_macri',
 'caba_voto_paso',
 'Usted votaría a Martin Lousteau  en la interna de Juntos para evitar que gane Jorge Macri',
 'nacional_voto',
 'Posibilidad existe que vaya a votar en las paso del 13 de agosto',
 'voto_2021',
 'pon2']

# %%
df.columns = listado_nuevo

# %%
df.sample(3)
# Out:
#     metodo     comuna       sexo       edad  \
# 796   CATI  Comuna 15  Masculino      18-29
# 41    CATI  Comuna 02   Femenino  Más de 50
# 678   CATI  Comuna 02   Femenino  Más de 50
#
#                                               estudios imagen_bullrich  \
# 796  Nivel Universitario o Terciario, ya sea comple...    Muy Negativa
# 41      Nivel Secundario, ya sea completo o incompleto    Muy Positiva
# 678     Nivel Secundario, ya sea completo o incompleto   Algo positiva
#
#     imagen_larreta imagen_lousteau imagen_jorge_macri   imagen_massa  \
# 796   Muy Negativa    Muy Negativa       Muy Negativa  Algo positiva
# 41   Algo positiva   Algo positiva      Algo positiva   Muy Negativa
# 678  Algo positiva   Algo positiva      Algo positiva  Algo negativa
#
#             votaria_lousteau      votaria_jorge_macri  \
# 796         Nunca lo votaría  Podría llegar a votarlo
# 41   Podría llegar a votarlo  Podría llegar a votarlo
# ...

# %%
nombre_base = "cols_"
nombre_archivo = os.path.join(os.getcwd(), nombre_base + encuesta)

print(nombre_archivo)
df.to_pickle(nombre_archivo)
#df.to_csv(nombre_archivo, sep=';', index=False, header=True, encoding='utf-8')
# Out:
# /home/raul/git/encuestas/archivos/cols_Base CABA Julio- Agosto.c1.sav
