# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import glob, os
from pathlib import Path
# print(pd.__version__)
# Configuro estilo seaborn
sns.set_theme(style='ticks', context='talk', palette='tab10')

# Suprimo los warnings
import warnings
warnings.simplefilter(action='ignore', category=(FutureWarning, UserWarning))

#from ydata_profiling import ProfileReport
#import dtale

# %%
# mostrar todas las columnas del pandas
pd.options.display.max_columns = None

# %%
encuesta = "cols_Base CABA Julio- Agosto.c1.pickle"

# %%
df = pd.read_pickle(encuesta)
df.sample(3)
# Out:
#          metodo     comuna       sexo       edad  \
# 562  Presencial  Comuna 09  Masculino  Más de 50
# 105        CATI  Comuna 05   Femenino  Más de 50
# 65         CATI  Comuna 03   Femenino      18-29
#
#                                              educacion paso_sufragara  \
# 562     Nivel Secundario, ya sea completo o incompleto  Algo negativa
# 105  Nivel Universitario o Terciario, ya sea comple...   Muy Positiva
# 65      Nivel Secundario, ya sea completo o incompleto   Muy Positiva
#
#     caba_paso_votaria caba_paso_votaria_lousteau   paso_votaria  \
# 562     Algo negativa              Algo negativa  Algo negativa
# 105     Algo positiva               Muy Positiva   Muy Positiva
# 65       Muy Positiva               Muy Positiva  Algo negativa
#
#                 P9                      P10                      P11  \
# 562  Algo positiva  Podría llegar a votarlo         Nunca lo votaría
# 105   Muy Negativa        Seguro lo votaría        Seguro lo votaría
# 65    Muy Negativa        Seguro lo votaría  Podría llegar a votarlo
#
#                                      P12  \
# 562  Jorge Adaro del Frente de Izquierda
# 105                Jorge Macri de Juntos
# 65             Martín Lousteau de Juntos
#
#                                                    P13  \
# 562  Si, haría eso para evitar que Jorge Macri sea ...
# 105                                                NaN
# 65                                                 NaN
#
#                                                    P14           P15  \
# 562  Gabriel Solano y Vilma Ripoll del Frente de Iz...  Muy probable
# 105  Patricia Bullrich y Luis Petri de Juntos por e...  Muy probable
# 65   Horacio Rodríguez Larreta y Gerardo Morales de...  Muy probable
#
#                                              P16     pon2
# 562  Luis Zamora de Autodeterminación y Libertad  0.81909
# 105  María Eugenia Vidal de Juntos por el Cambio  0.79881
# 65   María Eugenia Vidal de Juntos por el Cambio  1.23429

# %%
# Le agregamos una columna con la fecha de la eleccion a la que corresponde la encuesta
# paso 2023-08-13
# general 2023-10-22
# ballotage 2023-11-19
fecha_eleccion = "2023-08-13"
df['fecha'] = pd.to_datetime(fecha_eleccion, format='%Y-%m-%d')
df.sample(3)
# Out:
#          metodo     comuna      sexo       edad  \
# 237        CATI  Comuna 12  Femenino  Más de 50
# 422  Presencial  Comuna 12  Femenino      18-29
# 726        CATI  Comuna 12  Femenino      18-29
#
#                                           educacion paso_sufragara  \
# 237  Nivel Secundario, ya sea completo o incompleto   Muy Negativa
# 422  Nivel Secundario, ya sea completo o incompleto  Algo negativa
# 726  Nivel Secundario, ya sea completo o incompleto  Algo negativa
#
#     caba_paso_votaria caba_paso_votaria_lousteau   paso_votaria  \
# 237     Algo negativa              Algo positiva   Muy Negativa
# 422     Algo negativa              Algo negativa  Algo negativa
# 726     Algo positiva              Algo negativa  Algo positiva
#
#                 P9               P10                      P11  \
# 237  Algo positiva  Nunca lo votaría         Nunca lo votaría
# 422   Muy Negativa  Nunca lo votaría         Nunca lo votaría
# 726  Algo negativa  Nunca lo votaría  Podría llegar a votarlo
#
#                                                    P12  \
# 237  Leandro Santoro del Frente de Todos/ Unión por...
# 422                                No sabe/No contesta
# 726                              Jorge Macri de Juntos
#
#                                                    P13  \
# 237  Si, haría eso para evitar que Jorge Macri sea ...
# 422                                   No, no haría eso
# 726                                                NaN
#
#                                                    P14            P15  \
# 237  Juan Grabois y Paula Abal Medina del Frente de...   Muy probable
# 422  Gabriel Solano y Vilma Ripoll del Frente de Iz...   Muy probable
# 726  Horacio Rodríguez Larreta y Gerardo Morales de...  Algo probable
#
#                                              P16     pon2      fecha
# 237          Leandro Santoro del Frente de Todos  0.94294 2023-08-13
# 422  Luis Zamora de Autodeterminación y Libertad  1.08959 2023-08-13
# 726  María Eugenia Vidal de Juntos por el Cambio  1.18192 2023-08-13

# %%
type(df['fecha'])
# Out:
# pandas.core.series.Series

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 819 entries, 0 to 818
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   metodo                      819 non-null    category
#  1   comuna                      819 non-null    category
#  2   sexo                        819 non-null    category
#  3   edad                        819 non-null    category
#  4   educacion                   819 non-null    category
#  5   paso_sufragara              819 non-null    category
#  6   caba_paso_votaria           819 non-null    category
#  7   caba_paso_votaria_lousteau  819 non-null    category
#  8   paso_votaria                819 non-null    category
#  9   P9                          819 non-null    category
#  10  P10                         819 non-null    category
#  11  P11                         819 non-null    category
#  12  P12                         819 non-null    category
#  13  P13                         355 non-null    category
#  14  P14                         819 non-null    category
#  15  P15                         819 non-null    category
#  16  P16                         819 non-null    category
#  17  pon2                        819 non-null    float64
#  18  fecha                       819 non-null    datetime64[ns]
# dtypes: category(17), datetime64[ns](1), float64(1)
# memory usage: 27.2 KB
